# %%
# plots for new subsampling plots

# %%
import warnings   
warnings.simplefilter("ignore") 
import matplotlib as mpl
import matplotlib.pyplot as plt
import pylab
# %matplotlib notebook
# %matplotlib inline

import numpy as np

from scipy.stats import sem
import pickle

# %% [markdown]
# ## DME

# %%
with open("../results/dme_subsample_v2.pkl", "rb") as f:
    ss_dme, otu_ds_dme, otu_bh_dme, err_ds_dme,err_bh_dme = pickle.load(f)

# %%
fig_dme = plt.figure()
plt.errorbar(ss_dme, otu_ds_dme, yerr=err_ds_dme, lw=2, color = 'red', label = 'DS')
plt.errorbar(ss_dme, otu_bh_dme, yerr=err_bh_dme, lw=2, color = 'blue', label = 'BH')
pylab.legend(loc ='lower right', frameon=False)
#plt.suptitle('DME dataset')
plt.xlabel('samples per group', fontsize=20)
plt.ylabel('# bacteria detected', fontsize=20)

plt.plot([7.5, 16], [np.max(otu_bh_dme), np.max(otu_bh_dme)], 'k-', lw=2, linestyle='--', 
         color = 'orange')
plt.xticks(np.arange(2, 18, 2))
#plt.xlim([1.5, 18])
#plt.ylim([-10, 250])
plt.tick_params(labeltop='off', labelright='off')
plt.tick_params(labelsize=15)
plt.tight_layout()
fig_dme.savefig('plots/plots_v3/dme_subsamplbe.png')

# %%
# statistics
print(np.max(otu_bh_dme))
(8-16)/16*100
# Out:
# 73.71
# -50.0

# %% [markdown]
# ## UKT

# %%
with open("../results/ukt_subsample_v2.pkl", "rb") as f:
    ss_ukt, otu_ds_ukt, otu_bh_ukt, err_ds_ukt, err_bh_ukt = pickle.load(f)

# %%
fig_ukt = plt.figure()
plt.errorbar(ss_ukt, otu_ds_ukt, yerr=err_ds_ukt, lw=2, color = 'red', label='DS')
plt.errorbar(ss_ukt, otu_bh_ukt, yerr=err_bh_ukt, lw=2, color = 'blue', label='BH')
#pylab.legend(loc ='upper left', frameon=False)
#plt.suptitle('UKT dataset')
plt.xlabel('samples per group', fontsize=20)
plt.ylabel('# bacteria detected', fontsize=20)

#plt.xlim([5, 110])
#plt.ylim([-15, 500])

plt.plot([85, 100], [np.max(otu_bh_ukt), np.max(otu_bh_ukt)], 'k-', lw=2, 
         linestyle='--', color = 'orange')
plt.xticks(np.arange(10, 110, 20))
plt.yticks(np.arange(0, 140, 20))
plt.tick_params(labelsize=15)
plt.tight_layout()
fig_ukt.savefig("plots/plots_v3/ukt_subsample.png")

# %%
# statistics
print(np.max(otu_bh_ukt))
(85-100)/100*100
# Out:
# 64.88
# -15.0

# %% [markdown]
# ## DIBD

# %%
with open("../results/dibd_subsample_v2.pkl", "rb") as f:
    ss_dibd, otu_ds_dibd, otu_bh_dibd, err_ds_dibd, err_bh_dibd = pickle.load(f)

# %%
fig_dibd = plt.figure()
plt.errorbar(ss_dibd, otu_ds_dibd, yerr=err_ds_dibd, lw=2, color = 'red', label='DS')
plt.errorbar(ss_dibd, otu_bh_dibd, yerr=err_bh_dibd, lw=2, color = 'blue', label='BH')
#pylab.legend(loc ='lower right', frameon=False)
#plt.suptitle('DIBD dataset')
plt.xlabel('samples per group', fontsize=20)
plt.ylabel('# bacteria detected', fontsize=20)
plt.xlim([-2, 70])
#plt.ylim([-4, 160])
plt.plot([41, 65], [np.max(otu_bh_dibd), np.max(otu_bh_dibd)], 'k-', lw=2, 
         linestyle='--', color = 'orange')
plt.xticks(np.arange(0, 70, 10))
plt.tick_params(labelsize=15)
plt.tight_layout()
fig_dibd.savefig('plots/plots_v3/dibd_subsample.png')

# %%
# statistics
print(np.max(otu_bh_dibd))
(42-65)/65*100
# Out:
# 86.84
# -35.38461538461539

# %% [markdown]
# ## GCD

# %%
with open("../results/gcd_subsample_v2.pkl", "rb") as f:
    ss_gcd, otu_ds_gcd, otu_bh_gcd, err_ds_gcd, err_bh_gcd = pickle.load(f)

# %%
fig_gcd = plt.figure()
plt.errorbar(ss_gcd, otu_ds_gcd, yerr=err_ds_gcd, lw=2, color = 'red', label='DS')
plt.errorbar(ss_gcd, otu_bh_gcd, yerr=err_bh_gcd, lw=2, color = 'blue', label='BH')
#pylab.legend(loc ='lower right', frameon=False)
#plt.suptitle('CD dataset')
plt.xlabel('samples per group', fontsize=20)
plt.ylabel('# bacteria detected', fontsize=20)
plt.tick_params(labeltop='off', labelright='off')
plt.xticks(np.arange(20, 340,40))
plt.plot([260, 320], [np.max(otu_bh_gcd), np.max(otu_bh_gcd)], 'k-', lw=2, 
         linestyle='--', color = 'orange')
#plt.xlim([0, 340])
#plt.ylim([-30, 900])
plt.tick_params(labelsize=15)
plt.tight_layout()
fig_gcd.savefig('plots/plots_v3/gcd_subsample.png')

# %%
# statistics
print(np.max(otu_bh_gcd))
(260-320)/320*100
# Out:
# 713.04
# -18.75

# %% [markdown]
# ## American Gut

# %%
with open("../results/agp_subsample_v2.pkl", "rb") as f:
    ss_agp, otu_ds_agp, otu_bh_agp, err_ds_agp, err_bh_agp = pickle.load(f)

# %%
fig_agp = plt.figure()
plt.errorbar(ss_agp, otu_ds_agp, yerr=err_ds_agp, lw=2, color = 'red', label='DS')
plt.errorbar(ss_agp, otu_bh_agp, yerr=err_bh_agp, lw=2, color = 'blue', label='BH')
#pylab.legend(loc = 'lower right', frameon=False)
#plt.suptitle('AG plant dataset')
plt.xlabel('samples per group', fontsize=20)
plt.ylabel('# bacteria detected', fontsize=20)
#plt.xlim([20, 400])
#plt.ylim([-30, 750])
plt.plot([170, 350], [np.max(otu_bh_agp), np.max(otu_bh_agp)], 'k-', lw=2, 
         linestyle='--', color = 'orange')
plt.tick_params(labelsize=15)
plt.tight_layout()
fig_agp.savefig('plots/plots_v3/agp_subsample.png')

# %%
# statistics
print(np.max(otu_bh_agp))
(170-350)/350*100
# Out:
# 243.69
# -51.42857142857142

# %% [markdown]
# ### Antibiotic History

# %%
with open("../results/aga_subsample_v2.pkl", "rb") as f:
    ss_aga, otu_ds_aga, otu_bh_aga, err_ds_aga, err_bh_aga = pickle.load(f)

# %%
fig_aga = plt.figure()
plt.errorbar(ss_aga, otu_ds_aga, yerr=err_ds_aga, lw=2, color = 'red', label='DS')
plt.errorbar(ss_aga, otu_bh_aga, yerr=err_bh_aga, lw=2, color = 'blue', label='BH')
#pylab.legend(loc = 'lower right', frameon=False)
#plt.suptitle('AG antibiotic history')
plt.xlabel('samples per group', fontsize=20)
plt.ylabel('# bacteria detected', fontsize=20)
#plt.xlim([10, 180])
#plt.ylim([-30, 500])
plt.plot([80, 160], [np.max(otu_bh_aga), np.max(otu_bh_aga)], 'k-', lw=2, 
         linestyle='--', color = 'orange')
plt.tick_params(labelsize=15)
plt.tight_layout()
fig_aga.savefig('plots/plots_v3/aga_subsample.png')

# %%
# statistics
print(np.max(otu_bh_aga))
(80-160)/160*100
# Out:
# 230.5
# -50.0
