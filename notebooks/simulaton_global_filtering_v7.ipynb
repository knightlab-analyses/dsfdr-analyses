# %%
# normalization before simulation (final version)

# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
import pylab
# %matplotlib notebook

# %% [markdown]
# ## DIBD

# %%
with open("../results_global/results_filtering/simulation_dibd_norm_s20_filterSum_B100k_v2.pkl", "rb") as f:
    filtlev, B, nSample, num_nulls, p_bh, p_fbh, p_ds, err_bh, err_fbh, err_ds = pickle.load(f)

# %%
print(filtlev)
# Out:
# [0, 50, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1250, 1500, 1750, 2000]

# %%
print(B, nSample)
print(num_nulls)
# Out:
# 100000 20
# [867.0, 169.76868999999999, 132.59596999999999, 99.926670000000001, 82.869979999999998, 71.760800000000003, 63.731990000000003, 57.976129999999998, 53.963349999999998, 50.358170000000001, 47.627879999999998, 45.413739999999997, 40.779159999999997, 36.761490000000002, 33.850670000000001, 31.651620000000001]

# %%
print(np.nanmax(err_bh), np.nanmax(err_fbh), np.nanmax(err_ds))
# Out:
# 0.000872659492784 0.000877703128984 0.00088668678694

# %%
fig_dibd_fl = plt.figure()
plt.axhline(0.1, linestyle='--', color = 'green', markeredgewidth=0.0, label = 'nominal level')
plt.plot(filtlev, p_ds, linestyle='--', marker='o', color = 'red', markeredgewidth=0.0, label = 'DS')
plt.plot(filtlev, p_fbh, linestyle='--', marker='o', color = 'orange', markeredgewidth=0.0, label = 'FBH')
plt.plot(filtlev, p_bh, linestyle='--', marker='o', color = 'blue', markeredgewidth=0.0, label = 'BH')
pylab.legend(loc ='best', frameon=False)
#plt.suptitle('DIBD data simulation (B=100000, nSample=20, SE=0.0009)')
plt.xlabel('filter level', fontsize=20)
plt.ylabel('FDR/FWER', fontsize=20)
plt.tick_params(labeltop='off', labelright='off')
plt.tick_params(labelsize=15)
plt.tight_layout()
fig_dibd_fl.savefig('plots/plots_v3/dibd_simulation_global_fl.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
num_nulls[0]
# Out:
# 867.0

# %%
fig_dibd_nulls = plt.figure()
plt.plot(np.delete(filtlev, 0), np.delete(num_nulls,0), linestyle='--', marker='o', color = 'purple', markeredgewidth=0.0)
pylab.legend(loc ='best', frameon=False)
#plt.suptitle('DIBD simulation (nSample=20, initial(non-filtered) # hypotheses=867)')
plt.xlabel('filter level', fontsize=20)
plt.ylabel('post filtering # hypotheses', fontsize=20)
plt.tick_params(labeltop='off', labelright='off')
plt.tick_params(labelsize=15)
plt.tight_layout()
fig_dibd_nulls.savefig('plots/plots_v3/dibd_simulation_global_nulls.png')
# Out:
# <img src="data:image/png;base64,..." width="640">
# /Users/serene/miniconda3/envs/gneiss_v2/lib/python3.5/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# ## CS

# %%
with open("../results_global/results_filtering/simulation_cs_norm_s20_filterSum_B100k.pkl", "rb") as f:
    filtlev, B, nSample, num_nulls, p_bh, p_fbh, p_ds, err_bh, err_fbh, err_ds = pickle.load(f)

# %%
print(filtlev)
print(num_nulls)
print(B, nSample)
# Out:
# [0, 50, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1250, 1500, 1750, 2000]
# [2817.0, 345.67050999999998, 238.79175000000001, 157.93594999999999, 123.31895, 104.60713, 91.638840000000002, 81.968580000000003, 74.790199999999999, 69.054500000000004, 64.510859999999994, 60.297370000000001, 52.229759999999999, 45.918320000000001, 40.615200000000002, 36.191400000000002]
# 100000 20

# %%
print(np.nanmax(err_bh), np.nanmax(err_fbh), np.nanmax(err_ds))
# Out:
# 0.000867621765331 0.000874138859214 0.000884488438702

# %%
fig_cs_fl = plt.figure()
# plt.axhline(0.1, linestyle='--', color = 'green', markeredgewidth=0.0, label = 'nominal level')
# plt.plot(filtlev, p_ds, linestyle='--', marker='o', color = 'red', markeredgewidth=0.0, label = 'DS')
# plt.plot(filtlev, p_fbh, linestyle='--', marker='o', color = 'orange', markeredgewidth=0.0, label = 'FBH')
# plt.plot(filtlev, p_bh, linestyle='--', marker='o', color = 'blue', markeredgewidth=0.0, label = 'BH')
# pylab.legend(loc ='best', frameon=False)
plt.axhline(0.1, linestyle='--', color = 'green', markeredgewidth=0.0)
plt.plot(filtlev, p_ds, linestyle='--', marker='o', color = 'red', markeredgewidth=0.0)
plt.plot(filtlev, p_fbh, linestyle='--', marker='o', color = 'orange', markeredgewidth=0.0)
plt.plot(filtlev, p_bh, linestyle='--', marker='o', color = 'blue', markeredgewidth=0.0)

#plt.suptitle('CS data simulation (B=100000, nSample=20, SE=0.0009)')
plt.xlabel('filter level', fontsize=20)
plt.ylabel('FDR/FWER', fontsize=20)
plt.tick_params(labeltop='off', labelright='off')
plt.tick_params(labelsize=15)
plt.tight_layout()
fig_cs_fl.savefig('plots/plots_v3/cs_simulation_global_fl.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
num_nulls[0]
# Out:
# 2817.0

# %%
fig_cs_nulls = plt.figure()
plt.plot(np.delete(filtlev, 0), np.delete(num_nulls, 0), linestyle='--', marker='o', color = 'purple', markeredgewidth=0.0)
pylab.legend(loc ='best', frameon=False)
#plt.suptitle( 'CS simulation (nSample=20, initial(non-filtered) # hypotheses=2817)')
plt.xlabel('filter level', fontsize=20)
plt.ylabel('post filtering # hypotheses', fontsize=20)
plt.tick_params(labeltop='off', labelright='off')
plt.tick_params(labelsize=15)
plt.tight_layout()
fig_cs_nulls.savefig('plots/plots_v3/cs_simulation_global_nulls.png')
# Out:
# <img src="data:image/png;base64,..." width="640">
# /Users/serene/miniconda3/envs/gneiss_v2/lib/python3.5/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# ## CFS

# %%
with open("../results_global/results_filtering/v7/simulation_cfs_filtering.pkl", "rb") as f:
    filtlev, B, num_nulls, p_bh, p_fbh, p_ds, err_bh, err_fbh, err_ds = pickle.load(f)

# %%
print(filtlev)
print(B)
# Out:
# [200, 400, 600, 800, 1000, 1500, 2000, 2500, 3000, 4000, 5000, 6000, 7000, 8000]
# 20000

# %%
print(np.nanmax(err_bh), np.nanmax(err_fbh), np.nanmax(err_ds))
# Out:
# 0.0019767676281 0.001966769155 0.00197098801105

# %%
plt.figure()
plt.plot(filtlev, p_ds, linestyle='--', marker='o', color = 'red', markeredgewidth=0.0, label = 'DS')
plt.plot(filtlev, p_fbh, linestyle='--', marker='o', color = 'orange', markeredgewidth=0.0, label = 'FBH')
plt.plot(filtlev, p_bh, linestyle='--', marker='o', color = 'blue', markeredgewidth=0.0, label = 'BH')
pylab.legend(loc ='best', frameon=False)
plt.suptitle('CFS data simulation (B=20000, nSample=25, SE=0.0019)')
plt.xlabel('filter level')
plt.ylabel('FDR/FWER')
plt.ylim([0, 0.1])
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# (0, 0.1)

# %%
plt.figure()
plt.plot(filtlev, num_nulls, linestyle='--', marker='o', color = 'purple', markeredgewidth=0.0)
pylab.legend(loc ='best', frameon=False)
plt.suptitle('CFS data simulation (nSample=25)')
plt.xlabel('filter level')
plt.ylabel('# hypotheses left')
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# /Users/serene/miniconda3/envs/gneiss/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# ## DME

# %%
with open("../results_global/results_filtering/simulation_dme_filtering.pkl", "rb") as f:
    filtlev, B, num_nulls, p_bh, p_fbh, p_ds, err_bh, err_fbh, err_ds = pickle.load(f)

# %%
print(filtlev)
print(B)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]
# 20000

# %%
print(num_nulls)
# Out:
# [75, 41, 31, 28, 21, 18, 14, 10, 7, 6]

# %%
print(np.nanmax(err_bh), np.nanmax(err_fbh), np.nanmax(err_ds))
# Out:
# 0.00205371879478 0.002055204386 0.00206801201851

# %%
plt.figure()
plt.plot(filtlev, p_ds, linestyle='--', marker='o', color = 'red', markeredgewidth=0.0, label = 'DS')
plt.plot(filtlev, p_fbh, linestyle='--', marker='o', color = 'orange', markeredgewidth=0.0, label = 'FBH')
plt.plot(filtlev, p_bh, linestyle='--', marker='o', color = 'blue', markeredgewidth=0.0, label = 'BH')
pylab.legend(loc ='best', frameon=False)
plt.suptitle('DME data simulation (B=20000, nSample=25, SE=0.002)')
plt.xlabel('filter level')
plt.ylabel('FDR/FWER')
plt.ylim([0, 0.15])
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# (0, 0.15)

# %%
plt.figure()
plt.plot(filtlev, num_nulls, linestyle='--', marker='o', color = 'purple', markeredgewidth=0.0)
pylab.legend(loc ='best', frameon=False)
plt.suptitle('DME data simulation (nSample=25)')
plt.xlabel('filter level')
plt.ylabel('# hypotheses left')
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# /Users/serene/miniconda3/envs/gneiss/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# ## AGP

# %%
with open("../results_global/results_filtering/v7/simulation_agp_filtering.pkl", "rb") as f:
    filtlev, B, num_nulls, p_bh, p_fbh, p_ds, err_bh, err_fbh, err_ds = pickle.load(f)

# %%
print(B, filtlev)
# Out:
# 20000 [500, 1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 12500, 15000, 16000]

# %%
print(np.nanmax(err_bh), np.nanmax(err_fbh), np.nanmax(err_ds))
# Out:
# 0.00208215663888 0.00207583412858 0.0020879668293

# %%
plt.figure()
plt.plot(filtlev, p_ds, linestyle='--', marker='o', color = 'red', markeredgewidth=0.0, label = 'DS')
plt.plot(filtlev, p_fbh, linestyle='--', marker='o', color = 'orange', markeredgewidth=0.0, label = 'FBH')
plt.plot(filtlev, p_bh, linestyle='--', marker='o', color = 'blue', markeredgewidth=0.0, label = 'BH')
pylab.legend(loc ='best', frameon=False)
plt.suptitle('AGP data simulation (B=20000, nSample=250, SE=0.002)')
plt.xlabel('filter level')
plt.ylabel('FDR/FWER')
plt.xlim([0, 16000])
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# (0, 16000)

# %%
plt.figure()
plt.plot(filtlev, num_nulls, linestyle='--', marker='o', color = 'purple', markeredgewidth=0.0)
pylab.legend(loc ='best', frameon=False)
plt.suptitle('AGP data simulation (nSample=250)')
plt.xlabel('filter level')
plt.ylabel('# hypotheses left')
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# /Users/serene/miniconda3/envs/gneiss/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
