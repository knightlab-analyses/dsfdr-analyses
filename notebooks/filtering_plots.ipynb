# %%
import warnings   
warnings.simplefilter("ignore") 
import matplotlib as mpl
import matplotlib.pyplot as plt
import pylab
# %matplotlib notebook

import numpy as np
import pandas as pd

from scipy.stats import sem
import pickle

# %% [markdown]
# ## CFS

# %%
with open("../results/cfs_filtering_updated.pkl", "rb") as f:
    filtlev, sig_bh_cfs, sig_ds_cfs = pickle.load(f)

# %%
fig_cs = plt.figure()
plt.plot(filtlev, sig_ds_cfs, linestyle='--', marker='o', markeredgewidth=0.0, color = 'red', label = 'DS')
plt.plot(filtlev, sig_bh_cfs, linestyle='--', marker='o', markeredgewidth=0.0, color = 'blue', label = 'BH')
pylab.legend(loc ='upper right', frameon=False)
plt.xlim([-20, 510])
plt.ylim([-2, 70])
plt.xlabel('filter level', fontsize=20)
plt.ylabel('# bacteria detected', fontsize=20)
plt.tick_params(labelsize=15)
plt.tight_layout()
fig_cs.savefig('plots/plots_v3/cfs_filtering.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# zoom in
fig_cs_zoom = plt.figure()
plt.plot(filtlev[0:20], sig_ds_cfs[0:20], linestyle='--', marker='o', markeredgewidth=0.0,
         color = 'red', label = 'DS')
plt.plot(filtlev[0:20], sig_bh_cfs[0:20], linestyle='--', marker='o', markeredgewidth=0.0,
         color = 'blue', label = 'BH')
plt.xlim([-5, 110])
plt.ylim([-2, 70])
plt.xlabel('filter level', fontsize=20)
plt.ylabel('# bacteria detected', fontsize=20)
plt.tick_params(labelsize=15)
plt.tight_layout()
fig_cs_zoom.savefig('plots/plots_v3/cfs_zoom_filtering.png', bbox_to_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## MLT

# %%
with open("../results/mlt_filtering_updated.pkl", "rb") as f:
    filtlev, sig_bh_mlt, sig_ds_mlt = pickle.load(f)

# %%
fig_mlt = plt.figure()
plt.plot(filtlev, sig_ds_mlt, linestyle='--', marker='o', 
         markeredgewidth=0.0, color = 'red', label = 'DS')
plt.plot(filtlev, sig_bh_mlt, linestyle='--', marker='o', 
         markeredgewidth=0.0, color = 'blue', label = 'BH')
plt.xlim([-10, 510])
plt.ylim([-2, 45])
plt.xlabel('filter level', fontsize=20)
plt.ylabel('# bacteria detected', fontsize=20)
plt.tick_params(labelsize=15)
plt.tight_layout()
fig_mlt.savefig('plots/plots_v3/mlt_filtering.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# zoom in
fig_mlt_zoom = plt.figure()
plt.plot(filtlev[0:20], sig_ds_mlt[0:20], linestyle='--', marker='o', 
         markeredgewidth=0.0, color = 'red', label = 'DS')
plt.plot(filtlev[0:20], sig_bh_mlt[0:20], linestyle='--', marker='o', 
         markeredgewidth=0.0, color = 'blue', label = 'BH')
plt.xlabel('filter level', fontsize=20)
plt.ylabel('# bacteria detected', fontsize=20)
plt.tick_params(labelsize=15)
plt.xlim([-5, 110])
plt.ylim([-2, 45])
plt.tight_layout()
fig_mlt_zoom.savefig('plots/plots_v3/mlt_zoom_filtering.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## American Gut

# %%
# B = 1
with open("../results/ag_filtering_updated_B1.pkl", "rb") as f:
    filtlev, sig_bh_aga, sig_ds_aga, sig_bh_agp, sig_ds_agp = pickle.load(f)

# %%
fig_aga = plt.figure()
plt.plot(filtlev, sig_ds_aga, linestyle='--', marker='o', 
         markeredgewidth=0.0, color = 'red', label = 'DS')
plt.plot(filtlev, sig_bh_aga, linestyle='--', marker='o', 
         markeredgewidth=0.0, color = 'blue', label = 'BH')
plt.xlabel('filter level', fontsize=20)
plt.ylabel('# bacteria detected', fontsize=20)  
plt.tick_params(labelsize=15)
plt.xlim([-20, 510])
plt.ylim([300, 400])
plt.tight_layout()
fig_aga.savefig('plots/plots_v3/aga_filtering.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig_agp = plt.figure()
plt.plot(filtlev, sig_ds_agp, linestyle='--', marker='o', 
         markeredgewidth=0.0, color = 'red', label = 'DS')
plt.plot(filtlev, sig_bh_agp, linestyle='--', marker='o', 
         markeredgewidth=0.0, color = 'blue', label = 'BH')
plt.xlabel('filter level', fontsize=20)
plt.ylabel('# bacteria detected', fontsize=20)
plt.tick_params(labelsize=15)
plt.xlim([-20, 510])
plt.tight_layout()
fig_agp.savefig('plots/plots_v3/agp_filtering.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# B = 10
with open("../results/ag_filtering_v2.pkl", "rb") as f:
    filtlev, sig_bh_aga, sig_ds_aga, sig_bh_agp, sig_ds_agp = pickle.load(f)

# %%
fig_aga = plt.figure()
plt.plot(filtlev, sig_ds_aga, linestyle='--', marker='o', 
         markeredgewidth=0.0, color = 'red', label = 'DS')
plt.plot(filtlev, sig_bh_aga, linestyle='--', marker='o', 
         markeredgewidth=0.0, color = 'blue', label = 'BH')
plt.xlabel('filter level', fontsize=20)
plt.ylabel('# bacteria detected', fontsize=20)  
plt.tick_params(labelsize=15)
plt.tight_layout()
fig_aga.savefig('plots/plots_v3/aga_filtering.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig_agp = plt.figure()
plt.plot(filtlev, sig_ds_agp, linestyle='--', marker='o', 
         markeredgewidth=0.0, color = 'red', label = 'DS')
plt.plot(filtlev, sig_bh_agp, linestyle='--', marker='o', 
         markeredgewidth=0.0, color = 'blue', label = 'BH')
plt.xlabel('filter level', fontsize=20)
plt.ylabel('# bacteria detected', fontsize=20)
plt.tick_params(labelsize=15)
plt.tight_layout()
fig_agp.savefig('plots/plots_v3/agp_filtering.png')
# Out:
# <img src="data:image/png;base64,..." width="640">
