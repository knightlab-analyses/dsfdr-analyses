# %%
# revised normalization + filtering

# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
import pylab
# %matplotlib notebook

# %% [markdown]
# ## CS

# %%
with open("../results_global/results_downsampling/simulation_cs_norm_downSample_fl1000_B100k.pkl", "rb") as f:
    filtlev, B, sample_range, numbact, p_bh, p_fbh, p_ds, err_bh, err_fbh, err_ds = pickle.load(f)

# %%
print(sample_range)
print(B, filtlev, numbact)
# Out:
# [10, 15, 20, 25, 30, 35, 40, 50, 60, 70, 80, 90]
# 100000 1000 139

# %%
print(np.nanmax(err_bh), np.nanmax(err_fbh), np.nanmax(err_ds))
# Out:
# 0.000310567687506 0.000512831766727 0.000766211917035

# %%
# filtlev = 1000
fig_cs_ds = plt.figure()
# plt.axhline(0.1, linestyle='--', color = 'green', markeredgewidth=0.0, label = 'nominal level')
# plt.plot(sample_range, p_ds, linestyle='--', marker='o', color = 'red', markeredgewidth=0.0, label = 'DS')
# plt.plot(sample_range, p_fbh, linestyle='--', marker='o', color = 'orange', markeredgewidth=0.0, label = 'FBH')
# plt.plot(sample_range, p_bh, linestyle='--', marker='o', color = 'blue', markeredgewidth=0.0, label = 'BH')
# pylab.legend(loc ='best', frameon=False)
#plt.suptitle('CS data simulation (B=100000, FilterLev=1000, SE=0.0008)')
plt.axhline(0.1, linestyle='--', color = 'green', markeredgewidth=0.0)
plt.plot(sample_range, p_ds, linestyle='--', marker='o', color = 'red', markeredgewidth=0.0)
plt.plot(sample_range, p_fbh, linestyle='--', marker='o', color = 'orange', markeredgewidth=0.0)
plt.plot(sample_range, p_bh, linestyle='--', marker='o', color = 'blue', markeredgewidth=0.0)
plt.xlabel('Samples per group', fontsize=20)
plt.ylabel('FDR/FWER', fontsize=20)
plt.tick_params(labeltop='off', labelright='off')
plt.tick_params(labelsize=15)
plt.tight_layout()
fig_cs_ds.savefig('plots/plots_v3/cs_simulation_global_ds.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## DIBD

# %%
with open("../results_global/results_downsampling/simulation_dibd_norm_downSample_fl1000_B100k.pkl", "rb") as f:
    filtlev, B, sample_range, numbact, p_bh, p_fbh, p_ds, err_bh, err_fbh, err_ds = pickle.load(f)

# %%
print(sample_range)
print(B, filtlev, numbact)
# Out:
# [10, 15, 20, 25, 30, 35, 40, 50, 60, 70, 80, 90]
# 100000 1000 67

# %%
print(np.nanmax(err_bh), np.nanmax(err_fbh), np.nanmax(err_ds))
# Out:
# 0.000784698472993 0.000795171197902 0.000852845041286

# %%
# filtlev = 1000
fig_dibd_ds = plt.figure()
# plt.axhline(0.1, linestyle='--', color = 'green', markeredgewidth=0.0, label = 'nominal level')
# plt.plot(sample_range, p_ds, linestyle='--', marker='o', color = 'red', markeredgewidth=0.0, label = 'DS')
# plt.plot(sample_range, p_fbh, linestyle='--', marker='o', color = 'orange', markeredgewidth=0.0, label = 'FBH')
# plt.plot(sample_range, p_bh, linestyle='--', marker='o', color = 'blue', markeredgewidth=0.0, label = 'BH')
# pylab.legend(loc ='best', frameon=False)
#plt.suptitle('DIBD data simulation (B=100000, FilterLev=1000, SE=0.0008)')
plt.axhline(0.1, linestyle='--', color = 'green', markeredgewidth=0.0)
plt.plot(sample_range, p_ds, linestyle='--', marker='o', color = 'red', markeredgewidth=0.0)
plt.plot(sample_range, p_fbh, linestyle='--', marker='o', color = 'orange', markeredgewidth=0.0)
plt.plot(sample_range, p_bh, linestyle='--', marker='o', color = 'blue', markeredgewidth=0.0)
plt.xlabel('Samples per group', fontsize=20)
plt.ylabel('FDR/FWER', fontsize=20)
plt.tick_params(labeltop='off', labelright='off')
plt.tick_params(labelsize=15)
plt.tight_layout()
fig_dibd_ds.savefig('plots/plots_v3/dibd_simulation_global_ds.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## CFS

# %%
with open("../results_global/results_downsampling/v4/simulation_cfs.pkl", "rb") as f:
    sample_range, B, numbact, filterLev, p_bh, p_fbh, p_ds, err_bh, err_fbh, err_ds, pval_bh, pval_fbh, pval_ds = pickle.load(f)

# %%
print(sample_range)
print(B, filterLev, numbact)
# Out:
# [5, 6, 7, 8, 9, 10, 15, 20, 25]
# 100 100 697

# %%
print(np.nanmax(err_bh), np.nanmax(err_fbh), np.nanmax(err_ds))
# Out:
# 0.0 0.0 0.0219042913558

# %%
plt.figure()
plt.plot(sample_range, p_ds, linestyle='--', marker='o', color = 'red', markeredgewidth=0.0, label = 'DS')
plt.plot(sample_range, p_fbh, linestyle='--', marker='o', color = 'orange', markeredgewidth=0.0, label = 'FBH')
plt.plot(sample_range, p_bh, linestyle='--', marker='o', color = 'blue', markeredgewidth=0.0, label = 'BH')
pylab.legend(loc ='best', frameon=False)
plt.suptitle('CFS data simulation (B=100, FilterLev=100, SE=0.02)')
plt.xlabel('Samples per group')
plt.ylabel('FDR/FWER')
plt.ylim([0, 0.1])
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">
# (0, 0.1)

# %% [markdown]
# ## DME

# %%
with open("../results_global/results_downsampling/v4/simulation_dme.pkl", "rb") as f:
    sample_range, B, numbact, filterLev, p_bh, p_fbh, p_ds, err_bh, err_fbh, err_ds, pval_bh, pval_fbh, pval_ds = pickle.load(f)

# %%
print(sample_range)
print(B, filterLev, numbact)
# Out:
# [5, 6, 7, 8, 9, 10, 15, 20, 25]
# 100 100 75

# %%
print(np.nanmax(err_bh), np.nanmax(err_fbh), np.nanmax(err_ds))
# Out:
# 0.0287623491265 0.0256432399976 0.0272659924344

# %%
plt.figure()
plt.plot(sample_range, p_ds, linestyle='--', marker='o', color = 'red', markeredgewidth=0.0, label = 'DS')
plt.plot(sample_range, p_fbh, linestyle='--', marker='o', color = 'orange', markeredgewidth=0.0, label = 'FBH')
plt.plot(sample_range, p_bh, linestyle='--', marker='o', color = 'blue', markeredgewidth=0.0, label = 'BH')
pylab.legend(loc ='best', frameon=False)
plt.suptitle('DME data simulation (B=100, FilterLev=100, SE=0.027)')
plt.xlabel('Samples per group')
plt.ylabel('FDR/FWER')
plt.ylim([0, 0.11])
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">
# (0, 0.11)

# %% [markdown]
# ## GCD

# %%
with open("../results_global/results_downsampling/v4/simulation_gcd.pkl", "rb") as f:
    sample_range, B, numbact, filterLev, p_bh, p_fbh, p_ds, err_bh, err_fbh, err_ds, pval_bh, pval_fbh, pval_ds = pickle.load(f)

# %%
print(sample_range)
print(B, filterLev, numbact)
# Out:
# [10, 20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 225, 250]
# 100 5000 222

# %%
print(np.nanmax(err_bh), np.nanmax(err_fbh), np.nanmax(err_ds))
# Out:
# 0.01 0.01 0.0140705294136

# %%
plt.figure()
plt.plot(sample_range, p_ds, linestyle='--', marker='o', color = 'red', markeredgewidth=0.0, label = 'DS')
plt.plot(sample_range, p_fbh, linestyle='--', marker='o', color = 'orange', markeredgewidth=0.0, label = 'FBH')
plt.plot(sample_range, p_bh, linestyle='--', marker='o', color = 'blue', markeredgewidth=0.0, label = 'BH')
pylab.legend(loc ='best', frameon=False)
plt.suptitle('GCD data simulation (B=100, FilterLev=5000, SE=0.014)')
plt.xlabel('Samples per group')
plt.ylabel('FDR/FWER')
plt.ylim([0, 0.1])
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">
# (0, 0.1)

# %% [markdown]
# ## UKT

# %%
with open("../results_global/results_downsampling/v4/simulation_ukt.pkl", "rb") as f:
    sample_range, B, numbact, filterLev, p_bh, p_fbh, p_ds, err_bh, err_fbh, err_ds, pval_bh, pval_fbh, pval_ds = pickle.load(f)

# %%
print(sample_range)
print(B, filterLev, numbact)
# Out:
# [10, 20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 225, 250]
# 100 5000 414

# %%
print(np.nanmax(err_bh), np.nanmax(err_fbh), np.nanmax(err_ds))
# Out:
# 0.0 0.0 0.01

# %%
plt.figure()
plt.plot(sample_range, p_ds, linestyle='--', marker='o', color = 'red', markeredgewidth=0.0, label = 'DS')
plt.plot(sample_range, p_fbh, linestyle='--', marker='o', color = 'orange', markeredgewidth=0.0, label = 'FBH')
plt.plot(sample_range, p_bh, linestyle='--', marker='o', color = 'blue', markeredgewidth=0.0, label = 'BH')
pylab.legend(loc ='best', frameon=False)
plt.suptitle('UKT data simulation (B=100, FilterLev=5000, SE=0.01)')
plt.xlabel('Samples per group')
plt.ylabel('FDR/FWER')
plt.ylim([0, 0.1])
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">
# (0, 0.1)

# %% [markdown]
# ## AGA

# %%
with open("../results_global/results_downsampling/v4/simulation_aga.pkl", "rb") as f:
    sample_range, B, numbact, filterLev, p_bh, p_fbh, p_ds, err_bh, err_fbh, err_ds, pval_bh, pval_fbh, pval_ds = pickle.load(f)

# %%
print(sample_range)
print(B, filterLev, numbact)
# Out:
# [10, 20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 225, 250]
# 100 5000 244

# %%
print(np.nanmax(err_bh), np.nanmax(err_fbh), np.nanmax(err_ds))
# Out:
# 0.01 0.01 0.0238683256576

# %%
plt.figure()
plt.plot(sample_range, p_ds, linestyle='--', marker='o', color = 'red', markeredgewidth=0.0, label = 'DS')
plt.plot(sample_range, p_fbh, linestyle='--', marker='o', color = 'orange', markeredgewidth=0.0, label = 'FBH')
plt.plot(sample_range, p_bh, linestyle='--', marker='o', color = 'blue', markeredgewidth=0.0, label = 'BH')
pylab.legend(loc ='best', frameon=False)
plt.suptitle('AGA data simulation (B=100, FilterLev=5000, SE=0.02)')
plt.xlabel('Samples per group')
plt.ylabel('FDR/FWER')
plt.ylim([0, 0.1])
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">
# (0, 0.1)

# %% [markdown]
# ## AGP

# %%
with open("../results_global/results_downsampling/v4/simulation_agp.pkl", "rb") as f:
    sample_range, B, numbact, filterLev, p_bh, p_fbh, p_ds, err_bh, err_fbh, err_ds, pval_bh, pval_fbh, pval_ds = pickle.load(f)

# %%
print(sample_range)
print(B, filterLev, numbact)
# Out:
# [10, 20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 225, 250]
# 10000 5000 105

# %%
print(np.nanmax(err_bh), np.nanmax(err_fbh), np.nanmax(err_ds))
# Out:
# 0.000791260772035 0.00285190538701 0.00296108692942

# %%
plt.figure()
plt.plot(sample_range, p_ds, linestyle='--', marker='o', color = 'red', markeredgewidth=0.0, label = 'DS')
plt.plot(sample_range, p_fbh, linestyle='--', marker='o', color = 'orange', markeredgewidth=0.0, label = 'FBH')
plt.plot(sample_range, p_bh, linestyle='--', marker='o', color = 'blue', markeredgewidth=0.0, label = 'BH')
pylab.legend(loc ='best', frameon=False)
plt.suptitle('AGP data simulation (B=10000, FilterLev=1=5000, SE=0.002)')
plt.xlabel('Samples per group')
plt.ylabel('FDR/FWER')
plt.ylim([0, 0.1])
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">
# (0, 0.1)
